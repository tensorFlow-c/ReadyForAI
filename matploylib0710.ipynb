# %% [markdown]
# <a href="https://colab.research.google.com/github/zhoujiuzhou9/ReadyForAI/blob/v1/matploylib0710.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib

# %%
xpoints = np.array([0, 6])
ypoints = np.array([0, 100])

plt.plot(xpoints, ypoints)
plt.show()

# %%
x=np.linspace(-1,1,50)
y1=2*x+1
y2=x**2+1
plt.figure()
plt.plot(x,y1)

plt.figure()
plt.plot(x,y2)
plt.show()
