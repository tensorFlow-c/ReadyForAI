# %% [markdown]
# <a href="https://colab.research.google.com/github/zhoujiuzhou9/ReadyForAI/blob/main/pandas_acb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x_points=np.array([0,10])
y_points=np.array([0,200])

plt.plot(x_points,y_points)

# %%
import matplotlib.pyplot as plt

data = {'apple': 10, 'orange': 15, 'lemon': 5, 'lime': 20}
names = list(data.keys())
values = list(data.values())

fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True)
axs[0].bar(names, values)
axs[1].scatter(names, values)
axs[2].plot(names, values)
fig.suptitle('Categorical Plotting')
# Out:
# Text(0.5, 0.98, 'Categorical Plotting')

# %%
cat = ["bored", "happy", "bored", "bored", "happy", "bored"]
dog = ["happy", "happy", "happy", "happy", "bored", "bored"]
activity = ["combing", "drinking", "feeding", "napping", "playing", "washing"]

fig, ax = plt.subplots()
ax.plot(activity, dog, label="dog")
ax.plot(activity, cat, label="cat")
ax.legend()

plt.show()

# %%
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

fig = plt.figure()
ax = Axes3D(fig)
surf=ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.viridis)
# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)
 
plt.show()

# %%
s=pd.Series([1,3,6,np.nan,44,1])
print(s)
dates=pd.date_range('20160101',periods=6)
df=pd.DataFrame(np.random.randn(6,4),index=dates,columns=['a','b','c','d'])
print(df)
print(df.columns)
print(df.values)
print(df.sort_values(by='d'))
# Out:
# 0     1.0
# 1     3.0
# 2     6.0
# 3     NaN
# 4    44.0
# 5     1.0
# dtype: float64
#                    a         b         c         d
# 2016-01-01  0.217402  0.557494  1.094326  0.087508
# 2016-01-02  0.284772  1.192844 -0.264684  1.336107
# 2016-01-03  1.244735 -1.540851 -1.392849  1.080731
# 2016-01-04  0.486228  0.003092  0.768577 -0.361755
# 2016-01-05 -0.033278 -0.964726 -2.130802  0.475236
# 2016-01-06  1.631262  1.776151 -0.704447  1.227082
# Index(['a', 'b', 'c', 'd'], dtype='object')
# [[ 0.2174023   0.55749446  1.09432639  0.08750758]
#  [ 0.28477221  1.19284405 -0.2646839   1.33610689]
#  [ 1.24473475 -1.54085137 -1.39284898  1.08073143]
#  [ 0.48622823  0.00309166  0.76857652 -0.36175545]
#  [-0.03327765 -0.96472605 -2.13080204  0.47523618]
#  [ 1.63126158  1.77615099 -0.70444711  1.22708203]]
#                    a         b         c         d
# 2016-01-04  0.486228  0.003092  0.768577 -0.361755
# 2016-01-01  0.217402  0.557494  1.094326  0.087508
# ...

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df)
print(df.dtypes)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45
# calories    int64
# duration    int64
# dtype: object

# %%
s=pd.Series([1,3,6,np.nan,44,1])
# print(s)
dates=pd.date_range('20160101',periods=6)
df=pd.DataFrame(np.arange(24).reshape((6,4)),index=dates,columns=['A','B','C','D'])
print(df)

# print(df['A'],df.A)
print(df.iloc[3])
print(df.iloc[3:5,1:3])
print(df.iloc[[1,3,5],1:3])
# Out:
#              A   B   C   D
# 2016-01-01   0   1   2   3
# 2016-01-02   4   5   6   7
# 2016-01-03   8   9  10  11
# 2016-01-04  12  13  14  15
# 2016-01-05  16  17  18  19
# 2016-01-06  20  21  22  23
# A    12
# B    13
# C    14
# D    15
# Name: 2016-01-04 00:00:00, dtype: int64
#              B   C
# 2016-01-04  13  14
# 2016-01-05  17  18
#              B   C
# 2016-01-02   5   6
# 2016-01-04  13  14
# 2016-01-06  21  22

# %%
s=pd.Series([1,3,6,np.nan,44,1])
# print(s)
dates=pd.date_range('20160101',periods=6)
df=pd.DataFrame(np.arange(24).reshape((6,4)),index=dates,columns=['A','B','C','D'])
print(df)
df.iloc[2,2]=88888
print(df)
# Out:
#              A   B   C   D
# 2016-01-01   0   1   2   3
# 2016-01-02   4   5   6   7
# 2016-01-03   8   9  10  11
# 2016-01-04  12  13  14  15
# 2016-01-05  16  17  18  19
# 2016-01-06  20  21  22  23
#              A   B      C   D
# 2016-01-01   0   1      2   3
# 2016-01-02   4   5      6   7
# 2016-01-03   8   9  88888  11
# 2016-01-04  12  13     14  15
# 2016-01-05  16  17     18  19
# 2016-01-06  20  21     22  23

# %%
s=pd.Series([1,3,6,np.nan,44,1])
# print(s)
dates=pd.date_range('20160101',periods=6)
df=pd.DataFrame(np.arange(24).reshape((6,4)),index=dates,columns=['A','B','C','D'])
print(df)
df.iloc[2,2]=88888
print(df)
df.iloc[0,1]=np.nan
df.iloc[1,2]=np.nan

print(np.any(df.isnull())==True)
# Out:
#              A   B   C   D
# 2016-01-01   0   1   2   3
# 2016-01-02   4   5   6   7
# 2016-01-03   8   9  10  11
# 2016-01-04  12  13  14  15
# 2016-01-05  16  17  18  19
# 2016-01-06  20  21  22  23
#              A   B      C   D
# 2016-01-01   0   1      2   3
# 2016-01-02   4   5      6   7
# 2016-01-03   8   9  88888  11
# 2016-01-04  12  13     14  15
# 2016-01-05  16  17     18  19
# 2016-01-06  20  21     22  23
# True

# %%
df1=pd.DataFrame(np.arange(24).reshape((6,4)),index=dates,columns=['A','B','C','D'])
df2=pd.DataFrame(np.arange(24).reshape((6,4)),index=dates,columns=['A','B','C','D'])
df3=pd.DataFrame(np.arange(24).reshape((6,4)),index=dates,columns=['A','B','C','D'])
res=pd.concat([df1,df2,df3],axis=0,ignore_index=True)
print(res)
# Out:
#      A   B   C   D
# 0    0   1   2   3
# 1    4   5   6   7
# 2    8   9  10  11
# 3   12  13  14  15
# 4   16  17  18  19
# 5   20  21  22  23
# 6    0   1   2   3
# 7    4   5   6   7
# 8    8   9  10  11
# 9   12  13  14  15
# 10  16  17  18  19
# 11  20  21  22  23
# 12   0   1   2   3
# 13   4   5   6   7
# 14   8   9  10  11
# 15  12  13  14  15
# 16  16  17  18  19
# 17  20  21  22  23

# %%
df1=pd.DataFrame(np.arange(24).reshape((6,4)),index=dates,columns=['A','B','C','D'])
df2=pd.DataFrame(np.arange(24).reshape((6,4)),index=dates,columns=['A','B','C','D'])
df3=pd.DataFrame(np.arange(24).reshape((6,4)),index=dates,columns=['E','F','C','D'])
res=pd.concat([df1,df2,df3],axis=0,ignore_index=True)
print(res)
res=pd.concat([df1,df2,df3],join='inner',ignore_index=True)
# Out:
#        A     B   C   D     E     F
# 0    0.0   1.0   2   3   NaN   NaN
# 1    4.0   5.0   6   7   NaN   NaN
# 2    8.0   9.0  10  11   NaN   NaN
# 3   12.0  13.0  14  15   NaN   NaN
# 4   16.0  17.0  18  19   NaN   NaN
# 5   20.0  21.0  22  23   NaN   NaN
# 6    0.0   1.0   2   3   NaN   NaN
# 7    4.0   5.0   6   7   NaN   NaN
# 8    8.0   9.0  10  11   NaN   NaN
# 9   12.0  13.0  14  15   NaN   NaN
# 10  16.0  17.0  18  19   NaN   NaN
# 11  20.0  21.0  22  23   NaN   NaN
# 12   NaN   NaN   2   3   0.0   1.0
# 13   NaN   NaN   6   7   4.0   5.0
# 14   NaN   NaN  10  11   8.0   9.0
# 15   NaN   NaN  14  15  12.0  13.0
# 16   NaN   NaN  18  19  16.0  17.0
# 17   NaN   NaN  22  23  20.0  21.0

# %%
df1=pd.DataFrame(np.arange(24).reshape((6,4)),index=dates,columns=['A','B','C','D'])
df3=pd.DataFrame(np.arange(24).reshape((6,4)),index=dates,columns=['E','F','C','D'])
res=pd.merge(df1,df3,on='C')
print(res)
res=pd.concat([df1,df2,df3],join='inner',ignore_index=True)
# Out:
#     A   B   C  D_x   E   F  D_y
# 0   0   1   2    3   0   1    3
# 1   4   5   6    7   4   5    7
# 2   8   9  10   11   8   9   11
# 3  12  13  14   15  12  13   15
# 4  16  17  18   19  16  17   19
# 5  20  21  22   23  20  21   23

# %%
data=pd.Series(np.random.randn(1000),index=np.arange(1000))
data=data.cumsum()
data.plot()
plt.show()

# %%
data=pd.DataFrame(np.random.randn(1000,4),index=np.arange(1000),columns=list("ABCD"))


data=data.cumsum()
data.plot()
plt.show()
